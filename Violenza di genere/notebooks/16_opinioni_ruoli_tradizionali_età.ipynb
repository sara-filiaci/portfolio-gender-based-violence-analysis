# %% [markdown]
# Questa tabella è relativa solo all'anno 2018 e riporta la composizione percentuale (%) delle risposte di persone di nazionalità italiana e di età compresa fra i 18 e i 74 anni.

# %%
import pandas as pd

df = pd.read_csv(
    "../raw/Opinioni_ruoli_tradizionali_età.csv",
    sep=";",
    encoding="utf-8-sig",
)

df.head()
# Out:
#   FREQ Frequenza REF_AREA Territorio     DATA_TYPE  \
# 0    A   Annuale       IT     Italia  P18_74_AGROL
# 1    A   Annuale       IT     Italia  P18_74_AGROL
# 2    A   Annuale       IT     Italia  P18_74_AGROL
# 3    A   Annuale       IT     Italia  P18_74_AGROL
# 4    A   Annuale       IT     Italia  P18_74_AGROL
#
#                                           Indicatore SEX   Sesso     AGE  \
# 0  Persone di 18-74 anni per grado di accordo con...   M  Maschi  Y18-29
# 1  Persone di 18-74 anni per grado di accordo con...   M  Maschi  Y18-29
# 2  Persone di 18-74 anni per grado di accordo con...   M  Maschi  Y18-29
# 3  Persone di 18-74 anni per grado di accordo con...   M  Maschi  Y18-29
# 4  Persone di 18-74 anni per grado di accordo con...   M  Maschi  Y18-29
#
#           Età STEREOT_GENDROLEPARTNER  \
# 0  18-29 anni                 PRIOMEN
# 1  18-29 anni                 PRIOMEN
# 2  18-29 anni                 PRIOMEN
# 3  18-29 anni                 PRIOMEN
# 4  18-29 anni                 PRIOMEN
#
#   Stereotipi sui ruoli di genere, comportamenti nella coppia DEGREE_AGREEMENT  \
# 0  In condizioni di scarsità di lavoro,i datori d...                   STRAGR
# 1  In condizioni di scarsità di lavoro,i datori d...                   SOMAGR
# 2  In condizioni di scarsità di lavoro,i datori d...                 SOMDISAG
# 3  In condizioni di scarsità di lavoro,i datori d...                  STRODIS
# 4  In condizioni di scarsità di lavoro,i datori d...                   NOANSW
#
#           Grado di accordo  TIME_PERIOD  Osservazione  OBS_STATUS
# 0       'Molto d"'accordo'         2018           2.3         NaN
# 1  'Abbastanza d"'accordo'         2018           5.1         NaN
# 2        'Poco d"'accordo'         2018          15.0         NaN
# 3  'Per niente d"'accordo'         2018          77.3         NaN
# 4             Non risponde         2018           0.3         NaN

# %%
# Per ogni colonna: numero di valori unici + elenco valori

for col in df.columns:
    print("=" * 60)
    print(f"Colonna: {col}")
    print(f"Numero valori unici: {df[col].nunique(dropna=False)}")
    print("Valori unici:")
    print(df[col].unique())
    print("\n")
# Out:
# ============================================================
# Colonna: FREQ
# Numero valori unici: 1
# Valori unici:
# ['A']
#
#
# ============================================================
# Colonna: Frequenza
# Numero valori unici: 1
# Valori unici:
# ['Annuale']
#
#
# ============================================================
# Colonna: REF_AREA
# Numero valori unici: 1
# Valori unici:
# ['IT']
#
#
# ============================================================
# Colonna: Territorio
# Numero valori unici: 1
# Valori unici:
# ['Italia']
#
#
# ============================================================
# Colonna: DATA_TYPE
# Numero valori unici: 1
# Valori unici:
# ['P18_74_AGROL']
#
#
# ============================================================
# Colonna: Indicatore
# Numero valori unici: 1
# Valori unici:
# ['Persone di 18-74 anni per grado di accordo con alcuni stereotipi sui ruoli tradizionali di genere (composizione %)']
#
#
# ============================================================
# Colonna: SEX
# Numero valori unici: 3
# Valori unici:
# ['M' 'F' 'T']
#
#
# ============================================================
# Colonna: Sesso
# Numero valori unici: 3
# Valori unici:
# ['Maschi' 'Femmine' 'Totale']
#
#
# ============================================================
# Colonna: AGE
# Numero valori unici: 5
# Valori unici:
# ['Y18-29' 'Y30-44' 'Y45-59' 'Y60-74' 'TOTAL']
#
#
# ============================================================
# Colonna: Età
# Numero valori unici: 5
# Valori unici:
# ['18-29 anni' '30-44 anni' '45-59 anni' '60-74 anni' 'Totale']
#
#
# ============================================================
# Colonna: STEREOT_GENDROLEPARTNER
# Numero valori unici: 5
# Valori unici:
# ['PRIOMEN' 'MPRFAM' 'MTAKEDE' 'MLESHOUS' 'MISUCWOR']
#
#
# ============================================================
# Colonna: Stereotipi sui ruoli di genere, comportamenti nella coppia
# Numero valori unici: 5
# Valori unici:
# ['In condizioni di scarsità di lavoro,i datori di lavoro dovrebbero dare la precedenza agli uomini rispetto alle donne'
#  '\'È soprattutto l"\'uomo che deve provvedere alle necessità economiche della famiglia\''
#  '\'È l"\'uomo che deve prendere le decisioni più importanti riguardanti la famiglia\''
#  'Gli uomini sono meno adatti ad occuparsi delle faccende domestiche'
#  'Per l’uomo,più che per la donna,è molto importante avere successo nel lavoro']
#
#
# ============================================================
# Colonna: DEGREE_AGREEMENT
# Numero valori unici: 6
# Valori unici:
# ['STRAGR' 'SOMAGR' 'SOMDISAG' 'STRODIS' 'NOANSW' 'TOT']
#
#
# ============================================================
# Colonna: Grado di accordo
# Numero valori unici: 6
# Valori unici:
# ['\'Molto d"\'accordo\'' '\'Abbastanza d"\'accordo\''
#  '\'Poco d"\'accordo\'' '\'Per niente d"\'accordo\'' 'Non risponde'
#  'Totale']
#
#
# ============================================================
# Colonna: TIME_PERIOD
# Numero valori unici: 1
# Valori unici:
# [2018]
#
#
# ============================================================
# Colonna: Osservazione
# Numero valori unici: 232
# Valori unici:
# [  2.3   5.1  15.   77.3   0.3 100.    5.   12.1  25.   57.5   0.4   3.2
#    5.5  16.8  74.2   4.7  14.2  29.3  51.6   5.9  18.5  24.3  50.8   0.5
#    4.6  11.4  12.8  70.7  12.   21.8  17.3  48.5  15.6  73.4  10.2  18.2
#   22.3  48.7  10.6  21.9  49.3   0.8   5.2   9.1  13.4  71.7   0.6  19.
#   15.7  53.5   4.1   5.7  11.1  78.6   9.7  21.1  20.    8.9  20.3  14.9
#   54.9   1.1   7.6  12.4  62.8   2.1  25.3  13.   45.2   0.9   5.4   8.
#   11.6  74.    1.   27.5  17.8  39.1   1.4  11.   23.   14.4  49.2   2.4
#   10.4  13.3  70.4  17.1  50.9   4.4   6.3  75.4  10.   20.6  47.    0.7
#    9.3  21.   51.4   1.2   1.9  10.8  76.4   0.1  24.5  57.2   3.7  13.9
#   81.5  15.4  24.4  52.4  20.7  19.3  51.8  11.9  71.6   5.6  19.5  56.4
#    2.    4.3  10.1  83.4   0.2  10.7  20.5  49.4  26.2  18.   45.    4.8
#   11.3  12.9   7.2  15.1  61.6   2.2   3.8  85.6  11.2  49.1  12.6  50.4
#    1.3   7.   13.6  12.2  65.2  11.5  14.6   6.4   8.4  79.8  27.9  39.2
#    1.5  23.8  48.    3.1  70.5   7.5  17.   57.1   2.5   9.6  82.9  21.3
#   19.8  47.3  15.3  48.6   7.9  76.9  24.8  57.3  77.7   6.1  14.8  26.9
#   51.9   6.9  19.6  51.3  11.7  71.2  18.4   3.4  78.3  18.6  21.4  10.5
#   24.   17.6  47.2  10.3  13.1  71.1   9.2  57.7   9.5  82.2  19.1  48.9
#    9.9  22.7  13.7  52.5   7.3  14.3  12.3  64.1  23.1  13.8   7.1  77.
#   27.7  23.4  14.1   2.8   4.9  12.7   9.4  17.5  54.1  79.2  20.9  20.8
#   47.1   9.8  16.2  50. ]
#
#
# ============================================================
# Colonna: OBS_STATUS
# Numero valori unici: 1
# Valori unici:
# [nan]

# %%
# Rimozione colonne non informative o ridondanti:
# - colonne costanti (un solo valore per tutto il dataset)
# - colonne duplicate sul piano informativo
# - colonne completamente vuote

cols_to_drop = [
    "FREQ",               
    "Frequenza",          
    "REF_AREA",  
    "Territorio",         
    "DATA_TYPE", 
    "Indicatore",        
    "SEX",                     
    "AGE", 
    "STEREOT_GENDROLEPARTNER",        
    "DEGREE_AGREEMENT" ,
    "TIME_PERIOD",
    "OBS_STATUS"
]

df = df.drop(columns=cols_to_drop)

# Verifica struttura finale
print("Nuova shape:", df.shape)
print("Colonne rimanenti:", df.columns.tolist())
# Out:
# Nuova shape: (450, 5)
# Colonne rimanenti: ['Sesso', 'Età', 'Stereotipi sui ruoli di genere, comportamenti nella coppia', 'Grado di accordo', 'Osservazione']

# %%
# Standardizzazione nomi colonne:
# - tutto minuscolo
# - nomi più chiari e coerenti

df = df.rename(columns={
    "Sesso": "sesso",
    "Età": "età",
    "Stereotipi sui ruoli di genere, comportamenti nella coppia": "imput_affermazione",
    "Grado di accordo": "grado_accordo",
    "Osservazione": "percentuale"
})


# Eliminazione delle righe completamente vuote 
df = df.dropna(how="all")

# Stampa delle colonne e dei valori unici che contengono
for col in df.columns:
    print("\nColonna:", col)
    print(df[col].unique())
# Out:
# Colonna: sesso
# ['Maschi' 'Femmine' 'Totale']
#
# Colonna: età
# ['18-29 anni' '30-44 anni' '45-59 anni' '60-74 anni' 'Totale']
#
# Colonna: imput_affermazione
# ['In condizioni di scarsità di lavoro,i datori di lavoro dovrebbero dare la precedenza agli uomini rispetto alle donne'
#  '\'È soprattutto l"\'uomo che deve provvedere alle necessità economiche della famiglia\''
#  '\'È l"\'uomo che deve prendere le decisioni più importanti riguardanti la famiglia\''
#  'Gli uomini sono meno adatti ad occuparsi delle faccende domestiche'
#  'Per l’uomo,più che per la donna,è molto importante avere successo nel lavoro']
#
# Colonna: grado_accordo
# ['\'Molto d"\'accordo\'' '\'Abbastanza d"\'accordo\''
#  '\'Poco d"\'accordo\'' '\'Per niente d"\'accordo\'' 'Non risponde'
#  'Totale']
#
# Colonna: percentuale
# [  2.3   5.1  15.   77.3   0.3 100.    5.   12.1  25.   57.5   0.4   3.2
#    5.5  16.8  74.2   4.7  14.2  29.3  51.6   5.9  18.5  24.3  50.8   0.5
#    4.6  11.4  12.8  70.7  12.   21.8  17.3  48.5  15.6  73.4  10.2  18.2
#   22.3  48.7  10.6  21.9  49.3   0.8   5.2   9.1  13.4  71.7   0.6  19.
#   15.7  53.5   4.1   5.7  11.1  78.6   9.7  21.1  20.    8.9  20.3  14.9
#   54.9   1.1   7.6  12.4  62.8   2.1  25.3  13.   45.2   0.9   5.4   8.
#   11.6  74.    1.   27.5  17.8  39.1   1.4  11.   23.   14.4  49.2   2.4
#   10.4  13.3  70.4  17.1  50.9   4.4   6.3  75.4  10.   20.6  47.    0.7
#    9.3  21.   51.4   1.2   1.9  10.8  76.4   0.1  24.5  57.2   3.7  13.9
#   81.5  15.4  24.4  52.4  20.7  19.3  51.8  11.9  71.6   5.6  19.5  56.4
#    2.    4.3  10.1  83.4   0.2  10.7  20.5  49.4  26.2  18.   45.    4.8
#   11.3  12.9   7.2  15.1  61.6   2.2   3.8  85.6  11.2  49.1  12.6  50.4
#    1.3   7.   13.6  12.2  65.2  11.5  14.6   6.4   8.4  79.8  27.9  39.2
#    1.5  23.8  48.    3.1  70.5   7.5  17.   57.1   2.5   9.6  82.9  21.3
#   19.8  47.3  15.3  48.6   7.9  76.9  24.8  57.3  77.7   6.1  14.8  26.9
#   51.9   6.9  19.6  51.3  11.7  71.2  18.4   3.4  78.3  18.6  21.4  10.5
#   24.   17.6  47.2  10.3  13.1  71.1   9.2  57.7   9.5  82.2  19.1  48.9
#    9.9  22.7  13.7  52.5   7.3  14.3  12.3  64.1  23.1  13.8   7.1  77.
#   27.7  23.4  14.1   2.8   4.9  12.7   9.4  17.5  54.1  79.2  20.9  20.8
#   47.1   9.8  16.2  50. ]

# %%
# Pulizia valori categorici:
# - rimozione voci aggregate "Totale" dalle colonne rilevanti
# - normalizzazione label (sesso, età, grado_accordo)
# - pulizia quote / caratteri sporchi
# - pulizia testi in imput_affermazione
# - conversione percentuale a numerico


# Rimozione della voce aggregata "Totale" solo nelle colonne utili all'analisi
mask_totale = (
    df["sesso"].astype(str).str.strip().str.lower().eq("totale")
    | df["età"].astype(str).str.strip().str.lower().eq("totale")
    | df["grado_accordo"].astype(str).str.strip().str.lower().eq("totale")
)

print("Righe rimosse (contengono 'Totale'):", int(mask_totale.sum()))
df = df.loc[~mask_totale].copy()


# 1) sesso: minuscolo + standard
df["sesso"] = df["sesso"].str.lower().str.strip()

df["sesso"] = df["sesso"].replace({
    "maschi": "maschi",
    "femmine": "femmine"
})


# 2) età: rimozione stringa "anni"
df["età"] = df["età"].str.strip()

df["età"] = df["età"].str.replace(" anni", "", regex=False)


# 3) grado_accordo: rimozione quote sporche + normalizzazione
df["grado_accordo"] = df["grado_accordo"].str.strip()

df["grado_accordo"] = df["grado_accordo"].str.replace(r"^'+|'+$", "", regex=True)

df["grado_accordo"] = df["grado_accordo"].str.replace('d"\'accordo', "d'accordo", regex=False)

df["grado_accordo"] = df["grado_accordo"].str.replace('d"accordo', "d'accordo", regex=False)

df["grado_accordo"] = df["grado_accordo"].str.replace('"', "", regex=False)

df["grado_accordo"] = df["grado_accordo"].str.replace("\\", "", regex=False)

df["grado_accordo"] = df["grado_accordo"].str.lower().str.strip()

df["grado_accordo"] = df["grado_accordo"].replace({
    "molto d'accordo": "molto_d_accordo",
    "abbastanza d'accordo": "abbastanza_d_accordo",
    "poco d'accordo": "poco_d_accordo",
    "per niente d'accordo": "per_niente_d_accordo",
    "non risponde": "non_risponde"
})


# 4) imput_affermazione: pulizia testi
df["imput_affermazione"] = df["imput_affermazione"].str.strip()

df["imput_affermazione"] = df["imput_affermazione"].str.replace(r"^'+|'+$", "", regex=True)

df["imput_affermazione"] = df["imput_affermazione"].str.replace('l"\'uomo', "l'uomo", regex=False)

df["imput_affermazione"] = df["imput_affermazione"].str.replace('L"\'uomo', "L'uomo", regex=False)

df["imput_affermazione"] = df["imput_affermazione"].str.replace('"', "", regex=False)

df["imput_affermazione"] = df["imput_affermazione"].str.replace("\\", "", regex=False)

df["imput_affermazione"] = df["imput_affermazione"].str.replace(r"\s*,\s*", ", ", regex=True)

df["imput_affermazione"] = df["imput_affermazione"].str.replace(r"\s+", " ", regex=True)

df["imput_affermazione"] = df["imput_affermazione"].str.strip()


# 5) percentuale: conversione a numerico
df["percentuale"] = pd.to_numeric(df["percentuale"], errors="coerce")


# Verifica rapida post-pulizia
print("\nNuova shape:", df.shape)

for col in ["sesso", "età", "imput_affermazione", "grado_accordo"]:
    print("\nColonna:", col)
    print(df[col].unique())
# Out:
# Righe rimosse (contengono 'Totale'): 250
#
# Nuova shape: (200, 5)
#
# Colonna: sesso
# ['maschi' 'femmine']
#
# Colonna: età
# ['18-29' '30-44' '45-59' '60-74']
#
# Colonna: imput_affermazione
# ['In condizioni di scarsità di lavoro, i datori di lavoro dovrebbero dare la precedenza agli uomini rispetto alle donne'
#  "È soprattutto l'uomo che deve provvedere alle necessità economiche della famiglia"
#  "È l'uomo che deve prendere le decisioni più importanti riguardanti la famiglia"
#  'Gli uomini sono meno adatti ad occuparsi delle faccende domestiche'
#  'Per l’uomo, più che per la donna, è molto importante avere successo nel lavoro']
#
# Colonna: grado_accordo
# ['molto_d_accordo' 'abbastanza_d_accordo' 'poco_d_accordo'
#  'per_niente_d_accordo' 'non_risponde']

# %%
# Verifica finale post-pulizia (struttura + qualità base)

# 1) Dimensioni e info colonne
display(df.head(10))
df.info()

# 2) Tipi e missing
print("\nMissing values per colonna:")
display(df.isna().sum().sort_values(ascending=False))

# 3) Valori unici (conteggio) per colonna
print("\nNumero valori unici per colonna:")
display(df.nunique(dropna=False).sort_values(ascending=False))

# 4) Check duplicati (righe identiche)
print("\nRighe duplicate (identiche su tutte le colonne):", df.duplicated().sum())

# 5) Valori distinti per ogni colonna
for col in df.columns:
    print("\nColonna:", col)
    
    if col == "periodo":
        print(sorted(df[col].astype(int).unique().tolist()))
    else:
        print(df[col].unique())
# Out:
#      sesso    età                                 imput_affermazione  \
# 0   maschi  18-29  In condizioni di scarsità di lavoro, i datori ...
# 1   maschi  18-29  In condizioni di scarsità di lavoro, i datori ...
# 2   maschi  18-29  In condizioni di scarsità di lavoro, i datori ...
# 3   maschi  18-29  In condizioni di scarsità di lavoro, i datori ...
# 4   maschi  18-29  In condizioni di scarsità di lavoro, i datori ...
# 6   maschi  18-29  È soprattutto l'uomo che deve provvedere alle ...
# 7   maschi  18-29  È soprattutto l'uomo che deve provvedere alle ...
# 8   maschi  18-29  È soprattutto l'uomo che deve provvedere alle ...
# 9   maschi  18-29  È soprattutto l'uomo che deve provvedere alle ...
# 10  maschi  18-29  È soprattutto l'uomo che deve provvedere alle ...
#
#            grado_accordo  percentuale
# 0        molto_d_accordo          2.3
# 1   abbastanza_d_accordo          5.1
# 2         poco_d_accordo         15.0
# 3   per_niente_d_accordo         77.3
# 4           non_risponde          0.3
# 6        molto_d_accordo          5.0
# 7   abbastanza_d_accordo         12.1
# 8         poco_d_accordo         25.0
# 9   per_niente_d_accordo         57.5
# 10          non_risponde          0.4
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 268
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sesso               200 non-null    object
#  1   età                 200 non-null    object
#  2   imput_affermazione  200 non-null    object
#  3   grado_accordo       200 non-null    object
#  4   percentuale         200 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 9.4+ KB
#
# Missing values per colonna:
# sesso                 0
# età                   0
# imput_affermazione    0
# grado_accordo         0
# percentuale           0
# dtype: int64
# Numero valori unici per colonna:
# percentuale           146
# grado_accordo           5
# imput_affermazione      5
# età                     4
# sesso                   2
# dtype: int64
# Righe duplicate (identiche su tutte le colonne): 0
#
# Colonna: sesso
# ['maschi' 'femmine']
#
# Colonna: età
# ['18-29' '30-44' '45-59' '60-74']
#
# Colonna: imput_affermazione
# ['In condizioni di scarsità di lavoro, i datori di lavoro dovrebbero dare la precedenza agli uomini rispetto alle donne'
#  "È soprattutto l'uomo che deve provvedere alle necessità economiche della famiglia"
#  "È l'uomo che deve prendere le decisioni più importanti riguardanti la famiglia"
#  'Gli uomini sono meno adatti ad occuparsi delle faccende domestiche'
#  'Per l’uomo, più che per la donna, è molto importante avere successo nel lavoro']
#
# Colonna: grado_accordo
# ['molto_d_accordo' 'abbastanza_d_accordo' 'poco_d_accordo'
#  'per_niente_d_accordo' 'non_risponde']
#
# Colonna: percentuale
# [ 2.3  5.1 15.  77.3  0.3  5.  12.1 25.  57.5  0.4  3.2  5.5 16.8 74.2
#   4.7 14.2 29.3 51.6  5.9 18.5 24.3 50.8  0.5  4.6 11.4 12.8 70.7 12.
#  21.8 17.3 48.5 15.6 73.4 10.2 18.2 22.3 48.7 10.6 21.9 49.3  0.8  5.2
#   9.1 13.4 71.7  0.6 19.  15.7 53.5  4.1  5.7 11.1 78.6  9.7 21.1 20.
#   8.9 20.3 14.9 54.9  1.1  7.6 12.4 62.8  2.1 25.3 13.  45.2  0.9  5.4
#   8.  11.6 74.   1.  27.5 17.8 39.1  1.4 11.  23.  14.4 49.2  2.4  1.9
#  10.8 76.4  0.1 24.5 57.2  3.7 13.9 81.5 15.4 24.4 52.4 20.7 19.3 51.8
#  11.9 71.6  5.6 19.5 56.4  2.   4.3 10.1 83.4  0.2 10.7 20.5 49.4 10.4
#  26.2 18.  45.   4.8 11.3 12.9  7.2 15.1 61.6  2.2  3.8 85.6 11.2 21.
#  49.1 12.6 50.4  1.3  7.  13.6 12.2 65.2 11.5 14.6  6.4  8.4 79.8 13.3
#  27.9 39.2  1.5 23.8 48.   3.1]

# %%
# Salvataggio dataset pulito

output_path = "../data_clean/Opinioni_ruoli_tradizionali_età.csv"

df.to_csv(
    output_path,
    sep=",",
    index=False,
    encoding="utf-8-sig"
)

print("File salvato in:", output_path)
# Out:
# File salvato in: ../data_clean/Opinioni_ruoli_tradizionali_età.csv
