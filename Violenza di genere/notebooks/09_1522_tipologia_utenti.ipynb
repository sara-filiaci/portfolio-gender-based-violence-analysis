# %%
import pandas as pd

df = pd.read_csv("../raw/1522_tipologia_utenti.csv")

df.head()
# Out:
#   FREQ Frequenza REF_AREA Territorio DATA_TYPE       Indicatore TYPES_USERS  \
# 0    A   Annuale       IT     Italia     USERS  Utenti del 1522     ALL_VAL
# 1    A   Annuale       IT     Italia     USERS  Utenti del 1522     ALL_VAL
# 2    A   Annuale       IT     Italia     USERS  Utenti del 1522     ALL_VAL
# 3    A   Annuale       IT     Italia     USERS  Utenti del 1522     ALL_VAL
# 4    A   Annuale       IT     Italia     USERS  Utenti del 1522     ALL_VAL
#
#   Tipologia di utenza SEX   Sesso NATIONALITY Nazionalità  TIME_PERIOD  \
# 0     Chiamate valide   M  Maschi       WORLD       Mondo       2015.0
# 1     Chiamate valide   M  Maschi       WORLD       Mondo       2016.0
# 2     Chiamate valide   M  Maschi       WORLD       Mondo       2017.0
# 3     Chiamate valide   M  Maschi       WORLD       Mondo       2018.0
# 4     Chiamate valide   M  Maschi       WORLD       Mondo       2019.0
#
#    Osservazione  OBS_STATUS  Stato_osservazione
# 0        2201.0         NaN                 NaN
# 1        1690.0         NaN                 NaN
# 2        2119.0         NaN                 NaN
# 3        2557.0         NaN                 NaN
# 4        2342.0         NaN                 NaN

# %%
# Per ogni colonna: numero di valori unici + elenco valori

for col in df.columns:
    print("=" * 60)
    print(f"Colonna: {col}")
    print(f"Numero valori unici: {df[col].nunique(dropna=False)}")
    print("Valori unici:")
    print(df[col].unique())
    print("\n")
# Out:
# ============================================================
# Colonna: FREQ
# Numero valori unici: 98
# Valori unici:
# ['A'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2015,2,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2016,1,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2017,1,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2018,3,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2019,2,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2020,4,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2021,4,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2022,4,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2023,10,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,M,Maschi,WORLD,Mondo,2024,6,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2015,17,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2016,17,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2017,16,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2018,19,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2019,13,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2020,25,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2021,13,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2022,22,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2023,30,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,F,Femmine,WORLD,Mondo,2024,60,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2015,19,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2016,18,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2017,17,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2018,22,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2019,15,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2020,29,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2021,17,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2022,26,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2023,40,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,ALL_VAL,Chiamate valide,T,Totale,WORLD,Mondo,2024,66,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,USERS_CAL,Utenti che chiamano per sè
,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,M,Maschi,WORLD,Mondo,2023,2,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,F,Femmine,WORLD,Mondo,2018,1,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,F,Femmine,WORLD,Mondo,2023,1,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,F,Femmine,WORLD,Mondo,2024,7,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,T,Totale,WORLD,Mondo,2018,1,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,T,Totale,WORLD,Mondo,2023,3,,'
#  'A,Annuale,ITC2,\'Valle d"\'Aosta / Vallée d"\'Aoste\',USERS,Utenti del 1522,OTH_VALID,Altre chiamate valide,T,Totale,WORLD,Mondo,2024,7,,']
#
#
# ============================================================
# Colonna: Frequenza
# Numero valori unici: 2
# Valori unici:
# ['Annuale' nan]
#
#
# ============================================================
# Colonna: REF_AREA
# Numero valori unici: 27
# Valori unici:
# ['IT' 'ITC' 'ITC1' nan 'ITC3' 'ITC4' 'ITD' 'ITDA' 'ITD3' 'ITD4' 'ITD5'
#  'ITE' 'ITE1' 'ITE2' 'ITE3' 'ITE4' 'ITF' 'ITF1' 'ITF2' 'ITF3' 'ITF4'
#  'ITF5' 'ITF6' 'ITG' 'ITG1' 'ITG2' 'ITNI']
#
#
# ============================================================
# Colonna: Territorio
# Numero valori unici: 27
# Valori unici:
# ['Italia' 'Nord-ovest' 'Piemonte' nan 'Liguria' 'Lombardia' 'Nord-est'
#  'Trentino Alto Adige / Südtirol' 'Veneto' 'Friuli-Venezia Giulia'
#  'Emilia-Romagna' 'Centro' 'Toscana' 'Umbria' 'Marche' 'Lazio' 'Sud'
#  'Abruzzo' 'Molise' 'Campania' 'Puglia' 'Basilicata' 'Calabria' 'Isole'
#  'Sicilia' 'Sardegna' 'Non indicato']
#
#
# ============================================================
# Colonna: DATA_TYPE
# Numero valori unici: 2
# Valori unici:
# ['USERS' nan]
#
#
# ============================================================
# Colonna: Indicatore
# Numero valori unici: 2
# Valori unici:
# ['Utenti del 1522' nan]
#
#
# ============================================================
# Colonna: TYPES_USERS
# Numero valori unici: 7
# Valori unici:
# ['ALL_VAL' 'USERS_CAL' 'OPERATORS' 'FRIEND_ACQU' 'OTH_VALID' 'MISSING' nan]
#
#
# ============================================================
# Colonna: Tipologia di utenza
# Numero valori unici: 7
# Valori unici:
# ['Chiamate valide' 'Utenti che chiamano per sè' 'Da operatori'
#  'Da parenti/amici/conoscenti' 'Altre chiamate valide' 'Valore mancante'
#  nan]
#
#
# ============================================================
# Colonna: SEX
# Numero valori unici: 5
# Valori unici:
# ['M' 'F' 'NRP' 'T' nan]
#
#
# ============================================================
# Colonna: Sesso
# Numero valori unici: 5
# Valori unici:
# ['Maschi' 'Femmine' 'Non indicato' 'Totale' nan]
#
#
# ============================================================
# Colonna: NATIONALITY
# Numero valori unici: 2
# Valori unici:
# ['WORLD' nan]
#
#
# ============================================================
# Colonna: Nazionalità
# Numero valori unici: 2
# Valori unici:
# ['Mondo' nan]
#
#
# ============================================================
# Colonna: TIME_PERIOD
# Numero valori unici: 11
# Valori unici:
# [2015. 2016. 2017. 2018. 2019. 2020. 2021. 2022. 2023. 2024.   nan]
#
#
# ============================================================
# Colonna: Osservazione
# Numero valori unici: 1262
# Valori unici:
# [2201. 1690. 2119. ... 3449.  885. 5804.]
#
#
# ============================================================
# Colonna: OBS_STATUS
# Numero valori unici: 1
# Valori unici:
# [nan]
#
#
# ============================================================
# Colonna: Stato_osservazione
# Numero valori unici: 1
# Valori unici:
# [nan]

# %%
# Rimozione colonne non informative o ridondanti:
# - colonne costanti (un solo valore per tutto il dataset)
# - colonne duplicate sul piano informativo
# - colonne completamente vuote

cols_to_drop = [
    "FREQ",               
    "Frequenza",          
    "REF_AREA",          
    "DATA_TYPE",          
    "Indicatore",         
    "SEX",                
    "TYPES_USERS",
    "NATIONALITY", 
    "Nazionalità",    
    "OBS_STATUS",         
    "Stato_osservazione" 
]

df = df.drop(columns=cols_to_drop)

# Verifica struttura finale
print("Nuova shape:", df.shape)
print("Colonne rimanenti:", df.columns.tolist())
# Out:
# Nuova shape: (4197, 5)
# Colonne rimanenti: ['Territorio', 'Tipologia di utenza', 'Sesso', 'TIME_PERIOD', 'Osservazione']

# %%
# Standardizzazione nomi colonne:
# - tutto minuscolo
# - nomi più chiari e coerenti

df = df.rename(columns={
    "Territorio": "territorio",
    "Sesso": "sesso",
    "Tipologia di utenza": "tipologia_utenti",
    "TIME_PERIOD": "periodo",
    "Osservazione": "numero_vittime"
})


# Eliminazione delle righe completamente vuote 
df = df.dropna(how="all")

# Stampa delle colonne e dei valori unici che contengono
for col in df.columns:
    print("\nColonna:", col)
    print(df[col].unique())
# Out:
# Colonna: territorio
# ['Italia' 'Nord-ovest' 'Piemonte' 'Liguria' 'Lombardia' 'Nord-est'
#  'Trentino Alto Adige / Südtirol' 'Veneto' 'Friuli-Venezia Giulia'
#  'Emilia-Romagna' 'Centro' 'Toscana' 'Umbria' 'Marche' 'Lazio' 'Sud'
#  'Abruzzo' 'Molise' 'Campania' 'Puglia' 'Basilicata' 'Calabria' 'Isole'
#  'Sicilia' 'Sardegna' 'Non indicato']
#
# Colonna: tipologia_utenti
# ['Chiamate valide' 'Utenti che chiamano per sè' 'Da operatori'
#  'Da parenti/amici/conoscenti' 'Altre chiamate valide' 'Valore mancante']
#
# Colonna: sesso
# ['Maschi' 'Femmine' 'Non indicato' 'Totale']
#
# Colonna: periodo
# [2015. 2016. 2017. 2018. 2019. 2020. 2021. 2022. 2023. 2024.]
#
# Colonna: numero_vittime
# [2201. 1690. 2119. ... 3449.  885. 5804.]

# %%
# Pulizia colonna territorio:
# - uniformazione minuscolo
# - correzione denominazioni incoerenti / verbose

df["territorio"] = (
    df["territorio"]
    .str.lower()
    .str.strip()
    .str.replace("-", " ", regex=False)
)

df["territorio"] = df["territorio"].replace({
    "trentino alto adige / südtirol": "trentino alto adige"
})


# Uniformazione minuscolo per la colonna sesso e tipologia_utenti
df["sesso"] = df["sesso"].str.lower().str.strip()
df["tipologia_utenti"] = df["tipologia_utenti"].str.lower().str.strip()


# Rimozione della voce aggregata "totale" e "chiamate valide"
# da sesso e tipologia_utenti per evitare doppio conteggio

df = df[
    (df["sesso"] != "totale") &
    (df["tipologia_utenti"] != "chiamate valide")
]


# Conversione delle colonne numeriche da float a integer

df["periodo"] = df["periodo"].astype(int)
df["numero_vittime"] = df["numero_vittime"].astype(int)


# Verifica finale post-pulizia (struttura + qualità base)

# 1) Dimensioni e info colonne
display(df.head(10))
df.info()

# 2) Tipi e missing
print("\nMissing values per colonna:")
display(df.isna().sum().sort_values(ascending=False))

# 3) Valori unici (conteggio) per colonna
print("\nNumero valori unici per colonna:")
display(df.nunique(dropna=False).sort_values(ascending=False))

# 4) Check duplicati (righe identiche)
print("\nRighe duplicate (identiche su tutte le colonne):", df.duplicated().sum())

# 5) Valori distinti per ogni colonna
for col in df.columns:
    print("\nColonna:", col)
    
    if col == "periodo":
        print(sorted(df[col].astype(int).unique().tolist()))
    else:
        print(df[col].unique())
# Out:
#    territorio            tipologia_utenti   sesso  periodo  numero_vittime
# 37     italia  utenti che chiamano per sè  maschi     2015            1681
# 38     italia  utenti che chiamano per sè  maschi     2016            1284
# 39     italia  utenti che chiamano per sè  maschi     2017            1676
# 40     italia  utenti che chiamano per sè  maschi     2018            2153
# 41     italia  utenti che chiamano per sè  maschi     2019            1910
# 42     italia  utenti che chiamano per sè  maschi     2020            2890
# 43     italia  utenti che chiamano per sè  maschi     2021            3182
# 44     italia  utenti che chiamano per sè  maschi     2022            3220
# 45     italia  utenti che chiamano per sè  maschi     2023            2463
# 46     italia  utenti che chiamano per sè  maschi     2024            2569
# <class 'pandas.core.frame.DataFrame'>
# Index: 2197 entries, 37 to 4194
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   territorio        2197 non-null   object
#  1   tipologia_utenti  2197 non-null   object
#  2   sesso             2197 non-null   object
#  3   periodo           2197 non-null   int64
#  4   numero_vittime    2197 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 103.0+ KB
#
# Missing values per colonna:
# territorio          0
# tipologia_utenti    0
# sesso               0
# periodo             0
# numero_vittime      0
# dtype: int64
# Numero valori unici per colonna:
# numero_vittime      577
# territorio           26
# periodo              10
# tipologia_utenti      5
# sesso                 3
# dtype: int64
# Righe duplicate (identiche su tutte le colonne): 0
#
# Colonna: territorio
# ['italia' 'nord ovest' 'piemonte' 'liguria' 'lombardia' 'nord est'
#  'trentino alto adige' 'veneto' 'friuli venezia giulia' 'emilia romagna'
#  'centro' 'toscana' 'umbria' 'marche' 'lazio' 'sud' 'abruzzo' 'molise'
#  'campania' 'puglia' 'basilicata' 'calabria' 'isole' 'sicilia' 'sardegna'
#  'non indicato']
#
# Colonna: tipologia_utenti
# ['utenti che chiamano per sè' 'da operatori' 'da parenti/amici/conoscenti'
#  'altre chiamate valide' 'valore mancante']
#
# Colonna: sesso
# ['maschi' 'femmine' 'non indicato']
#
# Colonna: periodo
# [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
#